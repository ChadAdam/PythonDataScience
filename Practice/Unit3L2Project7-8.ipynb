# %% [markdown]
# ## Drill - Exercises in Bayes' Rule

# %% [markdown]
# ## Evaluating data sources
# Drill - find possible shortcomings of the theoretical or actual data sources to answer the given question.
# What could be done to either adjust the analysis or reframe the question so that you can answer it accurately?

# %% [markdown]
# 1 Data Source - Amsterdam availability data scraped from Airbnb on December 24th.
# Question: What are the popular neighborhoods in Amsterdam?
#
# The shortcoming here is Amsterdam availability's data is biased by the behavior of people who use Airbnb. It also
# skewed based on the exceptional circumstance of being collected near Christmas.
# You could adjust and limit your conclusion to finding the popular Amsterdam neighborhoods on Airbnb.
#
# 2 Data Source - Mental health services use on September 12, 2001 in San Francisco, CA and New York City, NY.
# Question: How do patterns of mental health service use vary between cities?
#
#
# The shortcoming is the exceptional circumstance of being collected so near a national tragedy. The bias is that comparing New York City at one of the sights of the tragedy to other cities.
#
# 3 Data Source: Armenian Pub Survey.
# Question: What are the most common reasons Armenians visit local pubs?
#
# People who take the survey will most likely be intoxicated.

# %% [markdown]
# ## Challenge - Beware of Monty Hall
#
# You pick a door. Then the host opens one of the other two doors to reveal a dud. But here's the wrinkle: the host now gives you the opportunity to switch your door. What should you do?
#
# Write up some notes on this problem, including how you think Bayes' Rule might apply. Drop a link to your notes below and discuss it with your mentor.
#
# ### Answer
#
# I would change to the other door when Monty opens one of the other doors. Because the probability of any door being the correct one changed the minute, I picked the first door, and as such the door not opened is most likely to be the correct one.
#
# Bayes' Rule might apply because it’s a conditional probabilities problem because once you pick your first door at random, the chances of any other door being correct is dependent on the door you picked first.
